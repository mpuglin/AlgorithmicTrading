# %% [markdown]
# <a href="https://colab.research.google.com/github/mpuglin/AlgorithmicTrading/blob/master/VWAP2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gspread pandas numpy google-auth -q

# %% [markdown]
# **VWAP STRATEGY**

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
import pandas as pd
from datetime import datetime
import numpy as np

# Authenticate and authorize Google Sheets
creds, _ = default()
gc = gspread.authorize(creds)

# Initialize global variables to track strategy performance
strategy_results = []

def get_clean_financial_data(sheet):
    """Download and clean financial data from a single Google Sheet worksheet"""
    # Get all data from the sheet
    rows = sheet.get_all_values()

    if len(rows) < 2:
        print(f"Skipping sheet {sheet.title}: Not enough rows.")
        return None

    headers = [h.strip() for h in rows[0]]
    required_columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']

    missing_columns = [col for col in required_columns if col not in headers]
    if missing_columns:
        print(f"Skipping sheet {sheet.title}: Missing required columns - {missing_columns}")
        return None

    col_indices = {col: headers.index(col) for col in required_columns}

    # Prepare data dictionary
    data = {
        'Date': [],
        'Open': [],
        'High': [],
        'Low': [],
        'Close': [],
        'Volume': []
    }

    for row in rows[1:]:
        if len(row) < len(headers):
            continue  # Skip incomplete rows

        try:
            # Parse date
            date_str = row[col_indices['Date']]
            parsed_date = parse_date(date_str)
            if not parsed_date:
                continue

            data['Date'].append(parsed_date)
            data['Open'].append(float(row[col_indices['Open']]))
            data['High'].append(float(row[col_indices['High']]))
            data['Low'].append(float(row[col_indices['Low']]))
            data['Close'].append(float(row[col_indices['Close']]))
            data['Volume'].append(int(float(row[col_indices['Volume']])))
        except ValueError as e:
            print(f"Skipping row in sheet {sheet.title} due to error: {e}")
            continue

    if not data['Date']:
        print(f"Skipping sheet {sheet.title}: No valid data found.")
        return None

    # Create DataFrame and clean
    df = pd.DataFrame(data)
    df.set_index('Date', inplace=True)
    df.sort_index(inplace=True)
    df = df.ffill()  # Forward fill missing values

    return df

def parse_date(date_str):
    """Parse date string with multiple possible formats"""
    formats = [
        '%m/%d/%Y %H:%M:%S',  # 01/02/2024 00:00:00
        '%m/%d/%Y',            # 01/02/2024
        '%Y-%m-%d %H:%M:%S',   # 2024-01-02 00:00:00
        '%Y-%m-%d',            # 2024-01-02
        '%d-%m-%Y %H:%M:%S',   # 02-01-2024 00:00:00
        '%d-%m-%Y'             # 02-01-2024
    ]

    for fmt in formats:
        try:
            return datetime.strptime(date_str, fmt)
        except ValueError:
            continue
    print(f"Warning: Could not parse date string: {date_str}")
    return None

def calculate_vwap(df):
    """Calculate Volume Weighted Average Price (VWAP) without lookahead bias"""
    # Calculate typical price (average of high, low, and close)
    df['Typical Price'] = (df['High'] + df['Low'] + df['Close']) / 3

    # Initialize cumulative columns
    df['Cumulative Volume'] = 0.0
    df['Cumulative PV'] = 0.0
    df['VWAP'] = 0.0

    # Compute cumulative values iteratively (row-by-row)
    cum_volume = 0.0
    cum_pv = 0.0

    for i in range(len(df)):
        cum_volume += df['Volume'].iloc[i]
        cum_pv += df['Typical Price'].iloc[i] * df['Volume'].iloc[i]

        df.loc[df.index[i], 'Cumulative Volume'] = cum_volume
        df.loc[df.index[i], 'Cumulative PV'] = cum_pv
        df.loc[df.index[i], 'VWAP'] = cum_pv / cum_volume if cum_volume > 0 else 0.0

    return df

def trading_strategy(data):
    """Pure VWAP trading strategy without lookahead bias"""
    data['Signal'] = 0  # Initialize signals

    # Calculate VWAP standard deviation bands using expanding window
    data['VWAP_std'] = data['VWAP'].expanding(min_periods=20).std()
    data['Upper Band'] = data['VWAP'] + data['VWAP_std']
    data['Lower Band'] = data['VWAP'] - data['VWAP_std']

    # Generate signals (no lookahead)
    for i in range(1, len(data)):
        # Buy when price approaches lower band (within 0.5%)
        if (data['Close'].iloc[i] - data['Lower Band'].iloc[i]) / data['Lower Band'].iloc[i] <= 0.005:
            data.loc[data.index[i], 'Signal'] = 1

        # Sell when price approaches upper band (within 0.5%)
        elif (data['Upper Band'].iloc[i] - data['Close'].iloc[i]) / data['Upper Band'].iloc[i] <= 0.005:
            data.loc[data.index[i], 'Signal'] = -1

    return data


def backtest_strategy(data, initial_capital=10000, transaction_fee=0.001):
    """Backtest the VWAP trading strategy"""
    position = 0  # 0 = No position, 1 = Long
    entry_price = 0
    portfolio_value = [initial_capital]  # Track portfolio value over time
    first_buy_occurred = False  # Flag to track the first buy signal
    transaction_log = []  # Log to store transaction details

    for i in range(len(data)):
        if data['Signal'].iloc[i] == 1 and position == 0:  # Buy signal
            if not first_buy_occurred:
                first_buy_occurred = True  # Mark the first buy signal
            position = 1
            entry_price = data['Close'].iloc[i]
            fee = round(portfolio_value[-1] * transaction_fee, 2)  # Calculate fee
            portfolio_value[-1] = round(portfolio_value[-1] - fee, 2)  # Deduct fee
            shares = round((portfolio_value[-1] * (1 - transaction_fee)) / entry_price, 2)  # Calculate number of shares
            transaction_log.append({
                'Date': data.index[i],
                'Action': 'Buy',
                'Price': round(entry_price, 2),
                'Shares': shares,
                'Fee': fee,
                'Portfolio Value After': portfolio_value[-1]
            })

        elif data['Signal'].iloc[i] == -1 and position == 1:  # Sell signal
            if first_buy_occurred:  # Only sell if the first buy has occurred
                position = 0
                exit_price = data['Close'].iloc[i]
                shares = transaction_log[-1]['Shares']  # Get shares from last buy transaction
                portfolio_value[-1] = round(shares * exit_price, 2)  # Update capital
                fee = round(portfolio_value[-1] * transaction_fee, 2)  # Calculate fee
                portfolio_value[-1] = round(portfolio_value[-1] - fee, 2)  # Deduct fee
                transaction_log.append({
                    'Date': data.index[i],
                    'Action': 'Sell',
                    'Price': round(exit_price, 2),
                    'Shares': shares,
                    'Fee': fee,
                    'Portfolio Value After': portfolio_value[-1]
                })

        portfolio_value.append(portfolio_value[-1])  # Update portfolio value for the next iteration

    # Remove the last duplicate value
    portfolio_value = portfolio_value[:-1]

    # Add portfolio value to the dataframe
    data['Portfolio Value'] = portfolio_value

    return data, pd.DataFrame(transaction_log)

def print_strategy_summary():
    """Print summary statistics of the strategy performance across all stocks"""
    if not strategy_results:
        print("No strategy results to summarize.")
        return

    df = pd.DataFrame(strategy_results)

    # Calculate win/loss metrics
    df['Result'] = np.where(df['Return'] >= 0, 'Win', 'Loss')
    win_rate = len(df[df['Result'] == 'Win']) / len(df) * 100

    # Calculate overall metrics
    avg_return = df['Return'].mean()
    best_stock = df.loc[df['Return'].idxmax()]
    worst_stock = df.loc[df['Return'].idxmin()]

    print("\n" + "="*60)
    print("VWAP STRATEGY SUMMARY REPORT".center(60))
    print("="*60)

    print(f"\nTotal Stocks Analyzed: {len(df)}")
    print(f"Winning Stocks: {len(df[df['Result'] == 'Win'])} ({win_rate:.1f}%)")
    print(f"Losing Stocks: {len(df[df['Result'] == 'Loss'])} ({100-win_rate:.1f}%)")
    print(f"\nAverage Return: {avg_return:.2f}%")

    print("\nBest Performing Stock:")
    print(f"  {best_stock['Stock']}: {best_stock['Return']:.2f}% (${best_stock['Final Value']:,.2f})")

    print("\nWorst Performing Stock:")
    print(f"  {worst_stock['Stock']}: {worst_stock['Return']:.2f}% (${worst_stock['Final Value']:,.2f})")

    print("\n" + "="*60)

# Main execution
if __name__ == "__main__":
    # Parameters
    INITIAL_CAPITAL = 10000
    TRANSACTION_FEE = 0.001  # 0.1%

    # Open the Google Sheet
    spreadsheet = gc.open('US_Stocks')

    # Process each worksheet
    for sheet in spreadsheet.worksheets():
        try:
            print(f"\n{'='*50}")
            print(f"Processing stock: {sheet.title}")
            print(f"{'='*50}")

            # Get and process data
            data = get_clean_financial_data(sheet)
            if data is None:
                continue

            data = calculate_vwap(data)
            data = trading_strategy(data)
            results, transactions = backtest_strategy(data, INITIAL_CAPITAL, TRANSACTION_FEE)

            # Calculate results
            final_value = results['Portfolio Value'].iloc[-1]
            returns_pct = ((final_value - INITIAL_CAPITAL) / INITIAL_CAPITAL * 100)

            # Store results for summary
            strategy_results.append({
                'Stock': sheet.title,
                'Final Value': final_value,
                'Return': returns_pct,
                'Trades': len(transactions),
                'First Trade': transactions['Date'].min() if len(transactions) > 0 else None,
                'Last Trade': transactions['Date'].max() if len(transactions) > 0 else None
            })

            # Print results
            print(f"\nFinal Portfolio Value: ${final_value:,.2f}")
            print(f"Return: {returns_pct:.2f}%")
            print(f"\nNumber of trades: {len(transactions)}")

            if len(transactions) > 0:
                print("\nFirst few transactions:")
                print(transactions.head())

        except Exception as e:
            print(f"Error processing sheet {sheet.title}: {e}")
            continue

    # Print final summary after all stocks are processed
    print_strategy_summary()
# Out:
# ==================================================
# Processing stock: AAPL
# ==================================================
#
# Final Portfolio Value: $10,016.32
# Return: 0.16%
#
# Number of trades: 5
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  184.40   54.12  10.00                9990.00
# 1 2024-02-05   Sell  187.68   54.12  10.16               10147.08
# 2 2024-02-13    Buy  185.04   54.73  10.15               10136.93
# 3 2024-05-03   Sell  183.38   54.73  10.04               10026.35
# 4 2025-04-04    Buy  188.38   53.12  10.03               10016.32
#
# ==================================================
# Processing stock: MSFT
# ==================================================
#
# Final Portfolio Value: $12,456.00
# Return: 24.56%
#
# Number of trades: 8
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-30    Buy  389.33   25.63  10.00                9990.00
# 1 2024-05-14   Sell  416.56   25.63  10.68               10665.75
# 2 2024-08-05    Buy  395.15   26.94  10.67               10655.08
# 3 2024-09-12   Sell  427.00   26.94  11.50               11491.88
# 4 2024-10-31    Buy  406.35   28.22  11.49               11480.39
#
# ==================================================
# Processing stock: AMZN
# ==================================================
#
# Final Portfolio Value: $12,774.76
# Return: 27.75%
#
# Number of trades: 4
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-08-02    Buy  167.90   59.44  10.00                9990.00
# 1 2024-09-11   Sell  184.52   59.44  10.97               10956.90
# 2 2025-04-03    Buy  178.41   61.29  10.96               10945.94
# 3 2025-05-12   Sell  208.64   61.29  12.79               12774.76
#
# ==================================================
# Processing stock: GOOGL
# ==================================================
#
# Final Portfolio Value: $12,868.17
# Return: 28.68%
#
# Number of trades: 8
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  140.10   71.23  10.00                9990.00
# 1 2024-02-07   Sell  145.54   71.23  10.37               10356.44
# 2 2024-02-16    Buy  140.52   73.55  10.36               10346.08
# 3 2024-03-14   Sell  143.10   73.55  10.52               10514.48
# 4 2024-09-06    Buy  150.92   69.53  10.51               10503.97
#
# ==================================================
# Processing stock: GOOG
# ==================================================
#
# Final Portfolio Value: $12,795.60
# Return: 27.96%
#
# Number of trades: 8
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  141.80   70.38  10.00                9990.00
# 1 2024-02-08   Sell  147.22   70.38  10.36               10350.98
# 2 2024-02-16    Buy  141.76   72.87  10.35               10340.63
# 3 2024-03-14   Sell  144.34   72.87  10.52               10507.54
# 4 2024-09-06    Buy  152.13   68.93  10.51               10497.03
#
# ==================================================
# Processing stock: META
# ==================================================
#
# Final Portfolio Value: $11,770.02
# Return: 17.70%
#
# Number of trades: 2
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2025-04-21    Buy  484.66   20.59  10.00                9990.00
# 1 2025-05-01   Sell  572.21   20.59  11.78               11770.02
#
# ==================================================
# Processing stock: TSLA
# ==================================================
#
# Final Portfolio Value: $20,843.18
# Return: 108.43%
#
# Number of trades: 8
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  191.59   52.09  10.00                9990.00
# 1 2024-07-01   Sell  209.86   52.09  10.93               10920.68
# 2 2025-03-10    Buy  222.15   49.06  10.92               10909.76
# 3 2025-03-24   Sell  278.39   49.06  13.66               13644.15
# 4 2025-04-08    Buy  221.86   61.38  13.64               13630.51
#
# ==================================================
# Processing stock: NVDA
# ==================================================
#
# Final Portfolio Value: $15,218.62
# Return: 52.19%
#
# Number of trades: 2
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2025-04-04    Buy   94.31  105.82  10.00                9990.00
# 1 2025-06-10   Sell  143.96  105.82  15.23               15218.62
#
# ==================================================
# Processing stock: JPM
# ==================================================
#
# Final Portfolio Value: $10,000.00
# Return: 0.00%
#
# Number of trades: 0
#
# ==================================================
# Processing stock: JNJ
# ==================================================
#
# Final Portfolio Value: $11,289.08
# Return: 12.89%
#
# Number of trades: 14
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  158.77   62.86  10.00                9990.00
# 1 2024-02-22   Sell  160.45   62.86  10.09               10075.80
# 2 2024-03-07    Buy  158.87   63.29  10.08               10065.72
# 3 2024-03-08   Sell  159.52   63.29  10.10               10085.92
# 4 2024-03-14    Buy  159.21   63.22  10.09               10075.83
#
# ==================================================
# Processing stock: V
# ==================================================
#
# Final Portfolio Value: $10,768.43
# Return: 7.68%
#
# Number of trades: 6
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-15    Buy  271.28   36.79  10.00                9990.00
# 1 2024-05-10   Sell  280.74   36.79  10.33               10318.09
# 2 2024-05-28    Buy  270.98   38.00  10.32               10307.77
# 3 2024-08-30   Sell  276.37   38.00  10.50               10491.56
# 4 2024-09-25    Buy  269.63   38.83  10.49               10481.07
#
# ==================================================
# Processing stock: PG
# ==================================================
#
# Final Portfolio Value: $11,860.06
# Return: 18.60%
#
# Number of trades: 7
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2025-01-06    Buy  160.60   62.14  10.00                9990.00
# 1 2025-01-27   Sell  169.66   62.14  10.54               10532.13
# 2 2025-04-07    Buy  160.23   65.60  10.53               10521.60
# 3 2025-04-17   Sell  170.63   65.60  11.19               11182.14
# 4 2025-04-24    Buy  159.53   69.95  11.18               11170.96
#
# ==================================================
# Processing stock: HD
# ==================================================
#
# Final Portfolio Value: $10,803.39
# Return: 8.03%
#
# Number of trades: 7
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-03    Buy  359.90   27.73  10.00                9990.00
# 1 2024-07-12   Sell  359.77   27.73   9.98                9966.44
# 2 2024-08-07    Buy  342.40   29.05   9.97                9956.47
# 3 2024-08-15   Sell  360.07   29.05  10.46               10449.57
# 4 2025-03-12    Buy  364.73   28.59  10.45               10439.12
#
# ==================================================
# Processing stock: MA
# ==================================================
#
# Final Portfolio Value: $11,059.86
# Return: 10.60%
#
# Number of trades: 4
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-05-01    Buy  442.07   22.58  10.00                9990.00
# 1 2024-07-31   Sell  463.71   22.58  10.47               10460.10
# 2 2024-08-05    Buy  442.00   23.62  10.46               10449.64
# 3 2024-08-15   Sell  468.71   23.62  11.07               11059.86
#
# ==================================================
# Processing stock: UNH
# ==================================================
#
# Final Portfolio Value: $13,300.61
# Return: 33.01%
#
# Number of trades: 13
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  503.61   19.82  10.00                9990.00
# 1 2024-02-22   Sell  526.50   19.82  10.44               10424.79
# 2 2024-02-28    Buy  498.28   20.88  10.42               10414.37
# 3 2024-05-09   Sell  507.03   20.88  10.59               10576.20
# 4 2024-05-30    Buy  481.65   21.91  10.58               10565.62
#
# ==================================================
# Processing stock: DIS
# ==================================================
#
# Final Portfolio Value: $11,570.54
# Return: 15.71%
#
# Number of trades: 4
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-05-23    Buy  100.66   99.15  10.00                9990.00
# 1 2024-11-14   Sell  109.12   99.15  10.82               10808.43
# 2 2025-03-11    Buy   97.90  110.18  10.81               10797.62
# 3 2025-05-08   Sell  105.12  110.18  11.58               11570.54
#
# ==================================================
# Processing stock: BAC
# ==================================================
#
# Final Portfolio Value: $12,240.42
# Return: 22.40%
#
# Number of trades: 6
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-02-05    Buy  32.99  302.52  10.00                9990.00
# 1 2024-02-12   Sell  33.62  302.52  10.17               10160.55
# 2 2024-02-13    Buy  32.75  309.63  10.16               10150.39
# 3 2024-02-15   Sell  34.07  309.63  10.55               10538.54
# 4 2025-04-03    Buy  37.22  282.58  10.54               10528.00
#
# ==================================================
# Processing stock: PYPL
# ==================================================
#
# Final Portfolio Value: $13,430.44
# Return: 34.30%
#
# Number of trades: 10
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-02-08    Buy  56.13  177.80  10.00                9990.00
# 1 2024-03-13   Sell  62.45  177.80  11.10               11092.51
# 2 2024-05-23    Buy  61.58  179.77  11.09               11081.42
# 3 2024-05-31   Sell  62.99  179.77  11.32               11312.39
# 4 2024-06-13    Buy  61.54  183.45  11.31               11301.08
#
# ==================================================
# Processing stock: ADBE
# ==================================================
#
# Final Portfolio Value: $10,275.53
# Return: 2.76%
#
# Number of trades: 5
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-02-15    Buy  590.44   16.90  10.00                9990.00
# 1 2024-06-28   Sell  555.54   16.90   9.39                9379.24
# 2 2024-10-01    Buy  502.80   18.62   9.38                9369.86
# 3 2024-12-06   Sell  552.96   18.62  10.30               10285.82
# 4 2024-12-12    Buy  474.63   21.63  10.29               10275.53
#
# ==================================================
# Processing stock: XOM
# ==================================================
#
# Final Portfolio Value: $10,706.00
# Return: 7.06%
#
# Number of trades: 3
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-12-16    Buy  108.47   92.01  10.00                9990.00
# 1 2025-03-25   Sell  116.59   92.01  10.73               10716.72
# 2 2025-04-04    Buy  104.34  102.50  10.72               10706.00
#
# ==================================================
# Processing stock: CMCSA
# ==================================================
#
# Final Portfolio Value: $10,028.06
# Return: 0.28%
#
# Number of trades: 7
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-02-07    Buy  42.86  232.85  10.00                9990.00
# 1 2024-03-11   Sell  43.54  232.85  10.14               10128.15
# 2 2024-03-14    Buy  42.82  236.06  10.13               10118.02
# 3 2024-03-28   Sell  43.35  236.06  10.23               10222.97
# 4 2024-04-01    Buy  42.28  241.31  10.22               10212.75
#
# ==================================================
# Processing stock: NFLX
# ==================================================
#
# Final Portfolio Value: $10,000.00
# Return: 0.00%
#
# Number of trades: 0
#
# ==================================================
# Processing stock: PFE
# ==================================================
#
# Final Portfolio Value: $11,546.05
# Return: 15.46%
#
# Number of trades: 7
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  27.02  369.36  10.00                9990.00
# 1 2024-03-11   Sell  28.37  369.36  10.48               10468.26
# 2 2024-04-04    Buy  26.65  392.02  10.47               10457.79
# 3 2024-05-06   Sell  28.16  392.02  11.04               11028.24
# 4 2024-06-17    Buy  26.98  407.94  11.03               11017.21
#
# ==================================================
# Processing stock: VZ
# ==================================================
#
# Final Portfolio Value: $12,506.51
# Return: 25.07%
#
# Number of trades: 20
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-02-08    Buy  39.91  250.06  10.00                9990.00
# 1 2024-02-21   Sell  41.10  250.06  10.28               10267.19
# 2 2024-02-26    Buy  39.69  258.17  10.27               10256.92
# 3 2024-03-25   Sell  40.87  258.17  10.55               10540.86
# 4 2024-04-12    Buy  39.72  264.85  10.54               10530.32
#
# ==================================================
# Processing stock: INTC
# ==================================================
#
# Final Portfolio Value: $10,709.81
# Return: 7.10%
#
# Number of trades: 3
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  42.92  232.53  10.00                9990.00
# 1 2024-03-07   Sell  46.15  232.53  10.73               10720.53
# 2 2024-03-08    Buy  44.00  243.16  10.72               10709.81
#
# ==================================================
# Processing stock: CSCO
# ==================================================
#
# Final Portfolio Value: $10,340.14
# Return: 3.40%
#
# Number of trades: 10
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  50.18  198.88  10.00                9990.00
# 1 2024-03-11   Sell  50.22  198.88   9.99                9977.76
# 2 2024-03-14    Buy  49.79  200.00   9.98                9967.78
# 3 2024-03-28   Sell  49.91  200.00   9.98                9972.02
# 4 2024-04-02    Buy  49.36  201.62   9.97                9962.05
#
# ==================================================
# Processing stock: KO
# ==================================================
#
# Final Portfolio Value: $11,050.33
# Return: 10.50%
#
# Number of trades: 12
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  59.90  166.61  10.00                9990.00
# 1 2024-02-01   Sell  60.98  166.61  10.16               10149.72
# 2 2024-02-06    Buy  59.94  168.99  10.15               10139.57
# 3 2024-02-20   Sell  60.70  168.99  10.26               10247.43
# 4 2024-02-29    Buy  60.02  170.39  10.25               10237.18
#
# ==================================================
# Processing stock: PEP
# ==================================================
#
# Final Portfolio Value: $11,053.20
# Return: 10.53%
#
# Number of trades: 17
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-02-09    Buy  167.67   59.52  10.00                9990.00
# 1 2024-02-12   Sell  170.61   59.52  10.15               10144.56
# 2 2024-02-14    Buy  167.52   60.44  10.14               10134.42
# 3 2024-02-23   Sell  169.60   60.44  10.25               10240.37
# 4 2024-02-26    Buy  168.26   60.74  10.24               10230.13
#
# ==================================================
# Processing stock: MRK
# ==================================================
#
# Final Portfolio Value: $9,990.00
# Return: -0.10%
#
# Number of trades: 1
#
# First few transactions:
#         Date Action   Price  Shares   Fee  Portfolio Value After
# 0 2024-07-30    Buy  115.25   86.59  10.0                 9990.0
#
# ==================================================
# Processing stock: ABT
# ==================================================
#
# Final Portfolio Value: $10,033.44
# Return: 0.33%
#
# Number of trades: 6
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-02-02    Buy  112.11   89.02  10.00                9990.00
# 1 2024-02-06   Sell  114.00   89.02  10.15               10138.13
# 2 2024-02-09    Buy  111.81   90.49  10.14               10127.99
# 3 2024-02-15   Sell  113.64   90.49  10.28               10273.00
# 4 2024-03-18    Buy  112.44   91.18  10.27               10262.73
#
# ==================================================
# Processing stock: T
# ==================================================
#
# Final Portfolio Value: $10,446.55
# Return: 4.47%
#
# Number of trades: 10
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-02-08    Buy  16.82  593.34  10.00                9990.00
# 1 2024-03-05   Sell  17.17  593.34  10.19               10177.46
# 2 2024-03-14    Buy  17.01  597.13  10.18               10167.28
# 3 2024-03-18   Sell  17.30  597.13  10.33               10320.02
# 4 2024-03-22    Buy  16.98  606.56  10.32               10309.70
#
# ==================================================
# Processing stock: CRM
# ==================================================
#
# Final Portfolio Value: $10,003.44
# Return: 0.03%
#
# Number of trades: 3
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-15    Buy  272.90   36.57  10.00                9990.00
# 1 2024-09-25   Sell  274.09   36.57  10.02               10013.45
# 2 2025-03-10    Buy  272.90   36.62  10.01               10003.44
#
# ==================================================
# Processing stock: WMT
# ==================================================
#
# Final Portfolio Value: $10,000.00
# Return: 0.00%
#
# Number of trades: 0
#
# ==================================================
# Processing stock: Sheet1
# ==================================================
# Skipping sheet Sheet1: Not enough rows.
#
# ==================================================
# Processing stock: ABBV
# ==================================================
#
# Final Portfolio Value: $13,302.99
# Return: 33.03%
#
# Number of trades: 12
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-04    Buy  167.90   59.44  10.00                9990.00
# 1 2024-06-20   Sell  172.13   59.44  10.23               10221.18
# 2 2024-07-02    Buy  165.96   61.47  10.22               10210.96
# 3 2024-07-17   Sell  175.27   61.47  10.77               10763.08
# 4 2024-11-12    Buy  171.09   62.78  10.76               10752.32
#
# ==================================================
# Processing stock: COST
# ==================================================
#
# Final Portfolio Value: $10,000.00
# Return: 0.00%
#
# Number of trades: 0
#
# ==================================================
# Processing stock: AVGO
# ==================================================
#
# Final Portfolio Value: $19,579.34
# Return: 95.79%
#
# Number of trades: 6
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-08-07    Buy  136.27   73.24  10.00                9990.00
# 1 2024-08-15   Sell  166.13   73.24  12.17               12155.19
# 2 2024-09-06    Buy  137.00   88.55  12.16               12143.03
# 3 2024-09-12   Sell  164.56   88.55  14.57               14557.22
# 4 2025-04-03    Buy  154.01   94.33  14.56               14542.66
#
# ==================================================
# Processing stock: DHR
# ==================================================
#
# Final Portfolio Value: $11,524.22
# Return: 15.24%
#
# Number of trades: 5
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-15    Buy  239.66   41.64  10.00                9990.00
# 1 2024-04-23   Sell  253.11   41.64  10.54               10528.96
# 2 2024-07-02    Buy  240.41   43.71  10.53               10518.43
# 3 2024-07-23   Sell  264.18   43.71  11.55               11535.76
# 4 2024-10-24    Buy  248.00   46.42  11.54               11524.22
#
# ==================================================
# Processing stock: MCD
# ==================================================
#
# Final Portfolio Value: $10,490.83
# Return: 4.91%
#
# Number of trades: 8
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  294.65   33.87  10.00                9990.00
# 1 2024-02-01   Sell  298.08   33.87  10.10               10085.87
# 2 2024-02-05    Buy  285.97   35.20  10.09               10075.78
# 3 2024-02-20   Sell  292.65   35.20  10.30               10290.98
# 4 2024-02-29    Buy  292.28   35.14  10.29               10280.69
#
# ==================================================
# Processing stock: MDT
# ==================================================
#
# Final Portfolio Value: $11,183.10
# Return: 11.83%
#
# Number of trades: 12
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-02-09    Buy  84.99  117.43  10.00                9990.00
# 1 2024-03-27   Sell  86.92  117.43  10.21               10196.81
# 2 2024-04-03    Buy  85.00  119.72  10.20               10186.61
# 3 2024-05-15   Sell  84.72  119.72  10.14               10132.54
# 4 2024-05-23    Buy  81.38  124.26  10.13               10122.41
#
# ==================================================
# Processing stock: BMY
# ==================================================
#
# Final Portfolio Value: $10,268.71
# Return: 2.69%
#
# Number of trades: 5
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  49.39  202.07  10.00                9990.00
# 1 2024-02-21   Sell  50.91  202.07  10.29               10277.09
# 2 2024-04-10    Buy  50.29  203.95  10.28               10266.81
# 3 2024-07-26   Sell  50.45  203.95  10.29               10278.99
# 4 2025-04-16    Buy  49.36  207.83  10.28               10268.71
#
# ==================================================
# Processing stock: NKE
# ==================================================
#
# Final Portfolio Value: $10,182.17
# Return: 1.82%
#
# Number of trades: 3
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  101.53   98.30  10.00                9990.00
# 1 2024-02-07   Sell  103.79   98.30  10.20               10192.36
# 2 2024-03-01    Buy  101.88   99.84  10.19               10182.17
#
# ==================================================
# Processing stock: PM
# ==================================================
#
# Final Portfolio Value: $10,358.72
# Return: 3.59%
#
# Number of trades: 4
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  91.76  108.76  10.00                9990.00
# 1 2024-03-08   Sell  92.68  108.76  10.08               10069.80
# 2 2024-03-22    Buy  90.88  110.58  10.07               10059.73
# 3 2024-04-19   Sell  93.77  110.58  10.37               10358.72
#
# ==================================================
# Processing stock: TMO
# ==================================================
#
# Final Portfolio Value: $11,278.15
# Return: 12.78%
#
# Number of trades: 11
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  538.98   18.52  10.00                9990.00
# 1 2024-02-01   Sell  552.23   18.52  10.23               10217.07
# 2 2024-02-13    Buy  538.60   18.93  10.22               10206.85
# 3 2024-02-14   Sell  548.27   18.93  10.38               10368.37
# 4 2024-04-16    Buy  554.55   18.66  10.37               10358.00
#
# ==================================================
# Processing stock: LIN
# ==================================================
#
# Final Portfolio Value: $12,623.42
# Return: 26.23%
#
# Number of trades: 10
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  404.83   24.65  10.00                9990.00
# 1 2024-02-01   Sell  408.65   24.65  10.07               10063.15
# 2 2024-02-02    Buy  407.09   24.67  10.06               10053.09
# 3 2024-02-06   Sell  415.56   24.67  10.25               10241.62
# 4 2024-05-02    Buy  419.62   24.36  10.24               10231.38
#
# ==================================================
# Processing stock: LOW
# ==================================================
#
# Final Portfolio Value: $10,613.00
# Return: 6.13%
#
# Number of trades: 5
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  214.52   46.52  10.00                9990.00
# 1 2024-02-01   Sell  220.23   46.52  10.25               10234.85
# 2 2024-05-21    Buy  224.86   45.43  10.23               10224.62
# 3 2024-07-12   Sell  234.08   45.43  10.63               10623.62
# 4 2025-03-11    Buy  232.67   45.57  10.62               10613.00
#
# ==================================================
# Processing stock: HON
# ==================================================
#
# Final Portfolio Value: $12,327.97
# Return: 23.28%
#
# Number of trades: 18
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-02-01    Buy  197.31   50.58  10.00                9990.00
# 1 2024-03-07   Sell  202.61   50.58  10.25               10237.76
# 2 2024-03-14    Buy  196.35   52.04  10.24               10227.52
# 3 2024-03-20   Sell  201.18   52.04  10.47               10458.94
# 4 2024-04-03    Buy  197.97   52.73  10.46               10448.48
#
# ==================================================
# Processing stock: AMD
# ==================================================
#
# Final Portfolio Value: $11,778.65
# Return: 17.79%
#
# Number of trades: 5
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-12    Buy  163.28   61.12  10.00                9990.00
# 1 2024-07-08   Sell  178.69   61.12  10.92               10910.61
# 2 2024-07-17    Buy  159.43   68.30  10.91               10899.70
# 3 2024-10-08   Sell  172.80   68.30  11.80               11790.44
# 4 2024-10-15    Buy  156.64   75.12  11.79               11778.65
#
# ==================================================
# Processing stock: SBUX
# ==================================================
#
# Final Portfolio Value: $12,603.66
# Return: 26.04%
#
# Number of trades: 10
#
# First few transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  93.03  107.28  10.00                9990.00
# 1 2024-02-06   Sell  95.67  107.28  10.26               10253.22
# 2 2024-02-15    Buy  93.22  109.77  10.25               10242.97
# 3 2024-02-21   Sell  95.02  109.77  10.43               10419.92
# 4 2024-02-28    Buy  93.00  111.82  10.42               10409.50
#
# ==================================================
# Processing stock: ORCL
# ==================================================
#
# Final Portfolio Value: $12,611.99
# Return: 26.12%
#
# Number of trades: 2
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2025-04-04    Buy  128.27    77.8  10.00                9990.00
# 1 2025-05-13   Sell  162.27    77.8  12.62               12611.99
#
# ==================================================
# Processing stock: UPS
# ==================================================
#
# Final Portfolio Value: $10,533.52
# Return: 5.34%
#
# Number of trades: 3
#
# First few transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  145.06   68.80  10.00                9990.00
# 1 2024-03-07   Sell  153.41   68.80  10.55               10544.06
# 2 2024-03-26    Buy  143.79   73.18  10.54               10533.52
#
# ============================================================
#                 VWAP STRATEGY SUMMARY REPORT
# ============================================================
#
# Total Stocks Analyzed: 50
# Winning Stocks: 49 (98.0%)
# Losing Stocks: 1 (2.0%)
#
# Average Return: 17.00%
#
# Best Performing Stock:
#   TSLA: 108.43% ($20,843.18)
#
# Worst Performing Stock:
#   MRK: -0.10% ($9,990.00)
#
# ============================================================

# %% [markdown]
# **COMPARE VWAP WITH BUY AND HOLD STRATEGY**

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
import pandas as pd
from datetime import datetime
import numpy as np

# Authenticate and authorize Google Sheets
creds, _ = default()
gc = gspread.authorize(creds)

# Initialize global variables to track strategy performance
strategy_results = []

def get_clean_financial_data(sheet):
    """Download and clean financial data from a single Google Sheet worksheet"""
    # Get all data from the sheet
    rows = sheet.get_all_values()

    if len(rows) < 2:
        print(f"Skipping sheet {sheet.title}: Not enough rows.")
        return None

    headers = [h.strip() for h in rows[0]]
    required_columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']

    missing_columns = [col for col in required_columns if col not in headers]
    if missing_columns:
        print(f"Skipping sheet {sheet.title}: Missing required columns - {missing_columns}")
        return None

    col_indices = {col: headers.index(col) for col in required_columns}

    # Prepare data dictionary
    data = {
        'Date': [],
        'Open': [],
        'High': [],
        'Low': [],
        'Close': [],
        'Volume': []
    }

    for row in rows[1:]:
        if len(row) < len(headers):
            continue  # Skip incomplete rows

        try:
            # Parse date
            date_str = row[col_indices['Date']]
            parsed_date = parse_date(date_str)
            if not parsed_date:
                continue

            data['Date'].append(parsed_date)
            data['Open'].append(float(row[col_indices['Open']]))
            data['High'].append(float(row[col_indices['High']]))
            data['Low'].append(float(row[col_indices['Low']]))
            data['Close'].append(float(row[col_indices['Close']]))
            data['Volume'].append(int(float(row[col_indices['Volume']])))
        except ValueError as e:
            print(f"Skipping row in sheet {sheet.title} due to error: {e}")
            continue

    if not data['Date']:
        print(f"Skipping sheet {sheet.title}: No valid data found.")
        return None

    # Create DataFrame and clean
    df = pd.DataFrame(data)
    df.set_index('Date', inplace=True)
    df.sort_index(inplace=True)
    df = df.ffill()  # Forward fill missing values

    return df

def parse_date(date_str):
    """Parse date string with multiple possible formats"""
    formats = [
        '%m/%d/%Y %H:%M:%S',  # 01/02/2024 00:00:00
        '%m/%d/%Y',            # 01/02/2024
        '%Y-%m-%d %H:%M:%S',   # 2024-01-02 00:00:00
        '%Y-%m-%d',            # 2024-01-02
        '%d-%m-%Y %H:%M:%S',   # 02-01-2024 00:00:00
        '%d-%m-%Y'             # 02-01-2024
    ]

    for fmt in formats:
        try:
            return datetime.strptime(date_str, fmt)
        except ValueError:
            continue
    print(f"Warning: Could not parse date string: {date_str}")
    return None

def calculate_vwap(df):
    """Calculate Volume Weighted Average Price (VWAP) without lookahead bias"""
    # Calculate typical price (average of high, low, and close)
    df['Typical Price'] = (df['High'] + df['Low'] + df['Close']) / 3

    # Initialize cumulative columns
    df['Cumulative Volume'] = 0.0
    df['Cumulative PV'] = 0.0
    df['VWAP'] = 0.0

    # Compute cumulative values iteratively (row-by-row)
    cum_volume = 0.0
    cum_pv = 0.0

    for i in range(len(df)):
        cum_volume += df['Volume'].iloc[i]
        cum_pv += df['Typical Price'].iloc[i] * df['Volume'].iloc[i]

        df.loc[df.index[i], 'Cumulative Volume'] = cum_volume
        df.loc[df.index[i], 'Cumulative PV'] = cum_pv
        df.loc[df.index[i], 'VWAP'] = cum_pv / cum_volume if cum_volume > 0 else 0.0

    return df

def trading_strategy(data):
    """Pure VWAP trading strategy without lookahead bias"""
    data['Signal'] = 0  # Initialize signals

    # Calculate VWAP standard deviation bands using expanding window
    data['VWAP_std'] = data['VWAP'].expanding(min_periods=20).std()
    data['Upper Band'] = data['VWAP'] + data['VWAP_std']
    data['Lower Band'] = data['VWAP'] - data['VWAP_std']

    # Generate signals (no lookahead)
    for i in range(1, len(data)):
        # Buy when price approaches lower band (within 0.5%)
        if (data['Close'].iloc[i] - data['Lower Band'].iloc[i]) / data['Lower Band'].iloc[i] <= 0.005:
            data.loc[data.index[i], 'Signal'] = 1

        # Sell when price approaches upper band (within 0.5%)
        elif (data['Upper Band'].iloc[i] - data['Close'].iloc[i]) / data['Upper Band'].iloc[i] <= 0.005:
            data.loc[data.index[i], 'Signal'] = -1

    return data

def buy_and_hold_strategy(data, initial_capital=10000, transaction_fee=0.001):
    """Simple buy-and-hold strategy for comparison"""
    # Buy at the first available price
    first_close = data['Close'].iloc[0]
    shares = (initial_capital * (1 - transaction_fee)) / first_close
    initial_fee = initial_capital * transaction_fee

    # Sell at the last available price
    last_close = data['Close'].iloc[-1]
    final_value = shares * last_close
    final_fee = final_value * transaction_fee
    final_value_after_fees = final_value - final_fee

    # Calculate portfolio value over time
    data['BH Portfolio Value'] = data['Close'] * shares
    data['BH Portfolio Value'] = data['BH Portfolio Value'] - (data['BH Portfolio Value'] * transaction_fee).shift(1).fillna(initial_fee)

    # Create transaction log
    transaction_log = pd.DataFrame([{
        'Date': data.index[0],
        'Action': 'Buy',
        'Price': first_close,
        'Shares': shares,
        'Fee': initial_fee,
        'Portfolio Value After': initial_capital - initial_fee
    }, {
        'Date': data.index[-1],
        'Action': 'Sell',
        'Price': last_close,
        'Shares': shares,
        'Fee': final_fee,
        'Portfolio Value After': final_value_after_fees
    }])

    return data, transaction_log

def backtest_strategy(data, initial_capital=10000, transaction_fee=0.001):
    """Backtest the VWAP trading strategy"""
    position = 0  # 0 = No position, 1 = Long
    entry_price = 0
    portfolio_value = [initial_capital]  # Track portfolio value over time
    first_buy_occurred = False  # Flag to track the first buy signal
    transaction_log = []  # Log to store transaction details

    for i in range(len(data)):
        if data['Signal'].iloc[i] == 1 and position == 0:  # Buy signal
            if not first_buy_occurred:
                first_buy_occurred = True  # Mark the first buy signal
            position = 1
            entry_price = data['Close'].iloc[i]
            fee = round(portfolio_value[-1] * transaction_fee, 2)  # Calculate fee
            portfolio_value[-1] = round(portfolio_value[-1] - fee, 2)  # Deduct fee
            shares = round((portfolio_value[-1] * (1 - transaction_fee)) / entry_price, 2)  # Calculate number of shares
            transaction_log.append({
                'Date': data.index[i],
                'Action': 'Buy',
                'Price': round(entry_price, 2),
                'Shares': shares,
                'Fee': fee,
                'Portfolio Value After': portfolio_value[-1]
            })

        elif data['Signal'].iloc[i] == -1 and position == 1:  # Sell signal
            if first_buy_occurred:  # Only sell if the first buy has occurred
                position = 0
                exit_price = data['Close'].iloc[i]
                shares = transaction_log[-1]['Shares']  # Get shares from last buy transaction
                portfolio_value[-1] = round(shares * exit_price, 2)  # Update capital
                fee = round(portfolio_value[-1] * transaction_fee, 2)  # Calculate fee
                portfolio_value[-1] = round(portfolio_value[-1] - fee, 2)  # Deduct fee
                transaction_log.append({
                    'Date': data.index[i],
                    'Action': 'Sell',
                    'Price': round(exit_price, 2),
                    'Shares': shares,
                    'Fee': fee,
                    'Portfolio Value After': portfolio_value[-1]
                })

        portfolio_value.append(portfolio_value[-1])  # Update portfolio value for the next iteration

    # Remove the last duplicate value
    portfolio_value = portfolio_value[:-1]

    # Add portfolio value to the dataframe
    data['VWAP Portfolio Value'] = portfolio_value

    return data, pd.DataFrame(transaction_log)

def print_strategy_summary():
    """Print summary statistics of the strategy performance across all stocks"""
    if not strategy_results:
        print("No strategy results to summarize.")
        return

    df = pd.DataFrame(strategy_results)

    # Calculate win/loss metrics for both strategies
    df['VWAP Result'] = np.where(df['VWAP Return'] >= 0, 'Win', 'Loss')
    df['BH Result'] = np.where(df['BH Return'] >= 0, 'Win', 'Loss')

    vwap_win_rate = len(df[df['VWAP Result'] == 'Win']) / len(df) * 100
    bh_win_rate = len(df[df['BH Result'] == 'Win']) / len(df) * 100

    # Calculate outperformance
    df['Outperformance'] = df['VWAP Return'] - df['BH Return']
    outperformance_count = len(df[df['Outperformance'] > 0])
    outperformance_pct = outperformance_count / len(df) * 100
    avg_outperformance = df['Outperformance'].mean()

    # Calculate overall metrics
    avg_vwap_return = df['VWAP Return'].mean()
    avg_bh_return = df['BH Return'].mean()

    best_vwap_stock = df.loc[df['VWAP Return'].idxmax()]
    worst_vwap_stock = df.loc[df['VWAP Return'].idxmin()]

    best_bh_stock = df.loc[df['BH Return'].idxmax()]
    worst_bh_stock = df.loc[df['BH Return'].idxmin()]

    print("\n" + "="*80)
    print("STRATEGY COMPARISON SUMMARY REPORT".center(80))
    print("="*80)

    print(f"\nTotal Stocks Analyzed: {len(df)}")

    print("\nVWAP Strategy Performance:")
    print(f"  Winning Stocks: {len(df[df['VWAP Result'] == 'Win'])} ({vwap_win_rate:.1f}%)")
    print(f"  Losing Stocks: {len(df[df['VWAP Result'] == 'Loss'])} ({100-vwap_win_rate:.1f}%)")
    print(f"  Average Return: {avg_vwap_return:.2f}%")

    print("\nBuy-and-Hold Strategy Performance:")
    print(f"  Winning Stocks: {len(df[df['BH Result'] == 'Win'])} ({bh_win_rate:.1f}%)")
    print(f"  Losing Stocks: {len(df[df['BH Result'] == 'Loss'])} ({100-bh_win_rate:.1f}%)")
    print(f"  Average Return: {avg_bh_return:.2f}%")

    print("\nStrategy Comparison:")
    print(f"  VWAP outperformed Buy-and-Hold in {outperformance_count} stocks ({outperformance_pct:.1f}%)")
    print(f"  Average outperformance: {avg_outperformance:.2f}%")

    print("\nBest Performing VWAP Stock:")
    print(f"  {best_vwap_stock['Stock']}: {best_vwap_stock['VWAP Return']:.2f}% (${best_vwap_stock['VWAP Final Value']:,.2f})")

    print("\nBest Performing Buy-and-Hold Stock:")
    print(f"  {best_bh_stock['Stock']}: {best_bh_stock['BH Return']:.2f}% (${best_bh_stock['BH Final Value']:,.2f})")

    print("\n" + "="*80)

# Main execution
if __name__ == "__main__":
    # Parameters
    INITIAL_CAPITAL = 10000
    TRANSACTION_FEE = 0.001  # 0.1%

    # Open the Google Sheet
    spreadsheet = gc.open('US_Stocks')

    # Process each worksheet
    for sheet in spreadsheet.worksheets():
        try:
            print(f"\n{'='*50}")
            print(f"Processing stock: {sheet.title}")
            print(f"{'='*50}")

            # Get and process data
            data = get_clean_financial_data(sheet)
            if data is None:
                continue

            data = calculate_vwap(data)
            data = trading_strategy(data)

            # Backtest both strategies
            vwap_results, vwap_transactions = backtest_strategy(data.copy(), INITIAL_CAPITAL, TRANSACTION_FEE)
            bh_results, bh_transactions = buy_and_hold_strategy(data.copy(), INITIAL_CAPITAL, TRANSACTION_FEE)

            # Merge results
            results = vwap_results.copy()
            results['BH Portfolio Value'] = bh_results['BH Portfolio Value']

            # Calculate results for both strategies
            vwap_final_value = results['VWAP Portfolio Value'].iloc[-1]
            vwap_returns_pct = ((vwap_final_value - INITIAL_CAPITAL) / INITIAL_CAPITAL * 100)

            bh_final_value = results['BH Portfolio Value'].iloc[-1]
            bh_returns_pct = ((bh_final_value - INITIAL_CAPITAL) / INITIAL_CAPITAL * 100)

            # Store results for summary
            strategy_results.append({
                'Stock': sheet.title,
                'VWAP Final Value': vwap_final_value,
                'VWAP Return': vwap_returns_pct,
                'VWAP Trades': len(vwap_transactions),
                'BH Final Value': bh_final_value,
                'BH Return': bh_returns_pct,
                'BH Trades': len(bh_transactions),
                'First Trade': vwap_transactions['Date'].min() if len(vwap_transactions) > 0 else None,
                'Last Trade': vwap_transactions['Date'].max() if len(vwap_transactions) > 0 else None
            })

            # Print results
            print(f"\nVWAP Strategy:")
            print(f"  Final Portfolio Value: ${vwap_final_value:,.2f}")
            print(f"  Return: {vwap_returns_pct:.2f}%")
            print(f"  Number of trades: {len(vwap_transactions)}")

            print(f"\nBuy-and-Hold Strategy:")
            print(f"  Final Portfolio Value: ${bh_final_value:,.2f}")
            print(f"  Return: {bh_returns_pct:.2f}%")
            print(f"  Number of trades: {len(bh_transactions)}")

            print(f"\nComparison:")
            print(f"  Difference: ${vwap_final_value - bh_final_value:,.2f}")
            print(f"  Percentage Difference: {vwap_returns_pct - bh_returns_pct:.2f}%")

            if len(vwap_transactions) > 0:
                print("\nFirst few VWAP transactions:")
                print(vwap_transactions.head())

        except Exception as e:
            print(f"Error processing sheet {sheet.title}: {e}")
            continue

    # Print final summary after all stocks are processed
    print_strategy_summary()
# Out:
# ==================================================
# Processing stock: AAPL
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,016.32
#   Return: 0.16%
#   Number of trades: 5
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $10,667.17
#   Return: 6.67%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-650.85
#   Percentage Difference: -6.51%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  184.40   54.12  10.00                9990.00
# 1 2024-02-05   Sell  187.68   54.12  10.16               10147.08
# 2 2024-02-13    Buy  185.04   54.73  10.15               10136.93
# 3 2024-05-03   Sell  183.38   54.73  10.04               10026.35
# 4 2025-04-04    Buy  188.38   53.12  10.03               10016.32
#
# ==================================================
# Processing stock: MSFT
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $12,456.00
#   Return: 24.56%
#   Number of trades: 8
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $12,893.64
#   Return: 28.94%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-437.64
#   Percentage Difference: -4.38%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-30    Buy  389.33   25.63  10.00                9990.00
# 1 2024-05-14   Sell  416.56   25.63  10.68               10665.75
# 2 2024-08-05    Buy  395.15   26.94  10.67               10655.08
# 3 2024-09-12   Sell  427.00   26.94  11.50               11491.88
# 4 2024-10-31    Buy  406.35   28.22  11.49               11480.39
#
# ==================================================
# Processing stock: AMZN
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $12,774.76
#   Return: 27.75%
#   Number of trades: 4
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $14,384.85
#   Return: 43.85%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-1,610.09
#   Percentage Difference: -16.10%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-08-02    Buy  167.90   59.44  10.00                9990.00
# 1 2024-09-11   Sell  184.52   59.44  10.97               10956.90
# 2 2025-04-03    Buy  178.41   61.29  10.96               10945.94
# 3 2025-05-12   Sell  208.64   61.29  12.79               12774.76
#
# ==================================================
# Processing stock: GOOGL
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $12,868.17
#   Return: 28.68%
#   Number of trades: 8
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $12,768.24
#   Return: 27.68%
#   Number of trades: 2
#
# Comparison:
#   Difference: $99.93
#   Percentage Difference: 1.00%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  140.10   71.23  10.00                9990.00
# 1 2024-02-07   Sell  145.54   71.23  10.37               10356.44
# 2 2024-02-16    Buy  140.52   73.55  10.36               10346.08
# 3 2024-03-14   Sell  143.10   73.55  10.52               10514.48
# 4 2024-09-06    Buy  150.92   69.53  10.51               10503.97
#
# ==================================================
# Processing stock: GOOG
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $12,795.60
#   Return: 27.96%
#   Number of trades: 8
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $12,724.73
#   Return: 27.25%
#   Number of trades: 2
#
# Comparison:
#   Difference: $70.87
#   Percentage Difference: 0.71%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  141.80   70.38  10.00                9990.00
# 1 2024-02-08   Sell  147.22   70.38  10.36               10350.98
# 2 2024-02-16    Buy  141.76   72.87  10.35               10340.63
# 3 2024-03-14   Sell  144.34   72.87  10.52               10507.54
# 4 2024-09-06    Buy  152.13   68.93  10.51               10497.03
#
# ==================================================
# Processing stock: META
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $11,770.02
#   Return: 17.70%
#   Number of trades: 2
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $20,235.52
#   Return: 102.36%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-8,465.50
#   Percentage Difference: -84.65%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2025-04-21    Buy  484.66   20.59  10.00                9990.00
# 1 2025-05-01   Sell  572.21   20.59  11.78               11770.02
#
# ==================================================
# Processing stock: TSLA
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $20,843.18
#   Return: 108.43%
#   Number of trades: 8
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $13,222.60
#   Return: 32.23%
#   Number of trades: 2
#
# Comparison:
#   Difference: $7,620.58
#   Percentage Difference: 76.21%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  191.59   52.09  10.00                9990.00
# 1 2024-07-01   Sell  209.86   52.09  10.93               10920.68
# 2 2025-03-10    Buy  222.15   49.06  10.92               10909.76
# 3 2025-03-24   Sell  278.39   49.06  13.66               13644.15
# 4 2025-04-08    Buy  221.86   61.38  13.64               13630.51
#
# ==================================================
# Processing stock: NVDA
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $15,218.62
#   Return: 52.19%
#   Number of trades: 2
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $29,977.89
#   Return: 199.78%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-14,759.27
#   Percentage Difference: -147.59%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2025-04-04    Buy   94.31  105.82  10.00                9990.00
# 1 2025-06-10   Sell  143.96  105.82  15.23               15218.62
#
# ==================================================
# Processing stock: JPM
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,000.00
#   Return: 0.00%
#   Number of trades: 0
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $15,680.20
#   Return: 56.80%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-5,680.20
#   Percentage Difference: -56.80%
#
# ==================================================
# Processing stock: JNJ
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $11,289.08
#   Return: 12.89%
#   Number of trades: 14
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $9,683.56
#   Return: -3.16%
#   Number of trades: 2
#
# Comparison:
#   Difference: $1,605.52
#   Percentage Difference: 16.06%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  158.77   62.86  10.00                9990.00
# 1 2024-02-22   Sell  160.45   62.86  10.09               10075.80
# 2 2024-03-07    Buy  158.87   63.29  10.08               10065.72
# 3 2024-03-08   Sell  159.52   63.29  10.10               10085.92
# 4 2024-03-14    Buy  159.21   63.22  10.09               10075.83
#
# ==================================================
# Processing stock: V
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,768.43
#   Return: 7.68%
#   Number of trades: 6
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $13,704.64
#   Return: 37.05%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-2,936.21
#   Percentage Difference: -29.36%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-15    Buy  271.28   36.79  10.00                9990.00
# 1 2024-05-10   Sell  280.74   36.79  10.33               10318.09
# 2 2024-05-28    Buy  270.98   38.00  10.32               10307.77
# 3 2024-08-30   Sell  276.37   38.00  10.50               10491.56
# 4 2024-09-25    Buy  269.63   38.83  10.49               10481.07
#
# ==================================================
# Processing stock: PG
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $11,860.06
#   Return: 18.60%
#   Number of trades: 7
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $10,794.61
#   Return: 7.95%
#   Number of trades: 2
#
# Comparison:
#   Difference: $1,065.45
#   Percentage Difference: 10.65%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2025-01-06    Buy  160.60   62.14  10.00                9990.00
# 1 2025-01-27   Sell  169.66   62.14  10.54               10532.13
# 2 2025-04-07    Buy  160.23   65.60  10.53               10521.60
# 3 2025-04-17   Sell  170.63   65.60  11.19               11182.14
# 4 2025-04-24    Buy  159.53   69.95  11.18               11170.96
#
# ==================================================
# Processing stock: HD
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,803.39
#   Return: 8.03%
#   Number of trades: 7
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $10,225.23
#   Return: 2.25%
#   Number of trades: 2
#
# Comparison:
#   Difference: $578.16
#   Percentage Difference: 5.78%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-03    Buy  359.90   27.73  10.00                9990.00
# 1 2024-07-12   Sell  359.77   27.73   9.98                9966.44
# 2 2024-08-07    Buy  342.40   29.05   9.97                9956.47
# 3 2024-08-15   Sell  360.07   29.05  10.46               10449.57
# 4 2025-03-12    Buy  364.73   28.59  10.45               10439.12
#
# ==================================================
# Processing stock: MA
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $11,059.86
#   Return: 10.60%
#   Number of trades: 4
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $13,452.32
#   Return: 34.52%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-2,392.46
#   Percentage Difference: -23.92%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-05-01    Buy  442.07   22.58  10.00                9990.00
# 1 2024-07-31   Sell  463.71   22.58  10.47               10460.10
# 2 2024-08-05    Buy  442.00   23.62  10.46               10449.64
# 3 2024-08-15   Sell  468.71   23.62  11.07               11059.86
#
# ==================================================
# Processing stock: UNH
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $13,300.61
#   Return: 33.01%
#   Number of trades: 13
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $5,692.87
#   Return: -43.07%
#   Number of trades: 2
#
# Comparison:
#   Difference: $7,607.74
#   Percentage Difference: 76.08%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  503.61   19.82  10.00                9990.00
# 1 2024-02-22   Sell  526.50   19.82  10.44               10424.79
# 2 2024-02-28    Buy  498.28   20.88  10.42               10414.37
# 3 2024-05-09   Sell  507.03   20.88  10.59               10576.20
# 4 2024-05-30    Buy  481.65   21.91  10.58               10565.62
#
# ==================================================
# Processing stock: DIS
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $11,570.54
#   Return: 15.71%
#   Number of trades: 4
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $13,145.49
#   Return: 31.45%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-1,574.95
#   Percentage Difference: -15.75%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-05-23    Buy  100.66   99.15  10.00                9990.00
# 1 2024-11-14   Sell  109.12   99.15  10.82               10808.43
# 2 2025-03-11    Buy   97.90  110.18  10.81               10797.62
# 3 2025-05-08   Sell  105.12  110.18  11.58               11570.54
#
# ==================================================
# Processing stock: BAC
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $12,240.42
#   Return: 22.40%
#   Number of trades: 6
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $13,074.20
#   Return: 30.74%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-833.78
#   Percentage Difference: -8.34%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-02-05    Buy  32.99  302.52  10.00                9990.00
# 1 2024-02-12   Sell  33.62  302.52  10.17               10160.55
# 2 2024-02-13    Buy  32.75  309.63  10.16               10150.39
# 3 2024-02-15   Sell  34.07  309.63  10.55               10538.54
# 4 2025-04-03    Buy  37.22  282.58  10.54               10528.00
#
# ==================================================
# Processing stock: PYPL
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $13,430.44
#   Return: 34.30%
#   Number of trades: 10
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $11,733.97
#   Return: 17.34%
#   Number of trades: 2
#
# Comparison:
#   Difference: $1,696.47
#   Percentage Difference: 16.96%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-02-08    Buy  56.13  177.80  10.00                9990.00
# 1 2024-03-13   Sell  62.45  177.80  11.10               11092.51
# 2 2024-05-23    Buy  61.58  179.77  11.09               11081.42
# 3 2024-05-31   Sell  62.99  179.77  11.32               11312.39
# 4 2024-06-13    Buy  61.54  183.45  11.31               11301.08
#
# ==================================================
# Processing stock: ADBE
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,275.53
#   Return: 2.76%
#   Number of trades: 5
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $6,911.87
#   Return: -30.88%
#   Number of trades: 2
#
# Comparison:
#   Difference: $3,363.66
#   Percentage Difference: 33.64%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-02-15    Buy  590.44   16.90  10.00                9990.00
# 1 2024-06-28   Sell  555.54   16.90   9.39                9379.24
# 2 2024-10-01    Buy  502.80   18.62   9.38                9369.86
# 3 2024-12-06   Sell  552.96   18.62  10.30               10285.82
# 4 2024-12-12    Buy  474.63   21.63  10.29               10275.53
#
# ==================================================
# Processing stock: XOM
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,706.00
#   Return: 7.06%
#   Number of trades: 3
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $10,966.74
#   Return: 9.67%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-260.74
#   Percentage Difference: -2.61%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-12-16    Buy  108.47   92.01  10.00                9990.00
# 1 2025-03-25   Sell  116.59   92.01  10.73               10716.72
# 2 2025-04-04    Buy  104.34  102.50  10.72               10706.00
#
# ==================================================
# Processing stock: CMCSA
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,028.06
#   Return: 0.28%
#   Number of trades: 7
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $8,023.80
#   Return: -19.76%
#   Number of trades: 2
#
# Comparison:
#   Difference: $2,004.26
#   Percentage Difference: 20.04%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-02-07    Buy  42.86  232.85  10.00                9990.00
# 1 2024-03-11   Sell  43.54  232.85  10.14               10128.15
# 2 2024-03-14    Buy  42.82  236.06  10.13               10118.02
# 3 2024-03-28   Sell  43.35  236.06  10.23               10222.97
# 4 2024-04-01    Buy  42.28  241.31  10.22               10212.75
#
# ==================================================
# Processing stock: NFLX
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,000.00
#   Return: 0.00%
#   Number of trades: 0
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $26,102.75
#   Return: 161.03%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-16,102.75
#   Percentage Difference: -161.03%
#
# ==================================================
# Processing stock: PFE
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $11,546.05
#   Return: 15.46%
#   Number of trades: 7
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $8,190.74
#   Return: -18.09%
#   Number of trades: 2
#
# Comparison:
#   Difference: $3,355.31
#   Percentage Difference: 33.55%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  27.02  369.36  10.00                9990.00
# 1 2024-03-11   Sell  28.37  369.36  10.48               10468.26
# 2 2024-04-04    Buy  26.65  392.02  10.47               10457.79
# 3 2024-05-06   Sell  28.16  392.02  11.04               11028.24
# 4 2024-06-17    Buy  26.98  407.94  11.03               11017.21
#
# ==================================================
# Processing stock: VZ
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $12,506.51
#   Return: 25.07%
#   Number of trades: 20
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $10,909.09
#   Return: 9.09%
#   Number of trades: 2
#
# Comparison:
#   Difference: $1,597.42
#   Percentage Difference: 15.97%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-02-08    Buy  39.91  250.06  10.00                9990.00
# 1 2024-02-21   Sell  41.10  250.06  10.28               10267.19
# 2 2024-02-26    Buy  39.69  258.17  10.27               10256.92
# 3 2024-03-25   Sell  40.87  258.17  10.55               10540.86
# 4 2024-04-12    Buy  39.72  264.85  10.54               10530.32
#
# ==================================================
# Processing stock: INTC
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,709.81
#   Return: 7.10%
#   Number of trades: 3
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $4,330.36
#   Return: -56.70%
#   Number of trades: 2
#
# Comparison:
#   Difference: $6,379.45
#   Percentage Difference: 63.79%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  42.92  232.53  10.00                9990.00
# 1 2024-03-07   Sell  46.15  232.53  10.73               10720.53
# 2 2024-03-08    Buy  44.00  243.16  10.72               10709.81
#
# ==================================================
# Processing stock: CSCO
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,340.14
#   Return: 3.40%
#   Number of trades: 10
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $12,944.06
#   Return: 29.44%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-2,603.92
#   Percentage Difference: -26.04%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  50.18  198.88  10.00                9990.00
# 1 2024-03-11   Sell  50.22  198.88   9.99                9977.76
# 2 2024-03-14    Buy  49.79  200.00   9.98                9967.78
# 3 2024-03-28   Sell  49.91  200.00   9.98                9972.02
# 4 2024-04-02    Buy  49.36  201.62   9.97                9962.05
#
# ==================================================
# Processing stock: KO
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $11,050.33
#   Return: 10.50%
#   Number of trades: 12
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $11,765.05
#   Return: 17.65%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-714.72
#   Percentage Difference: -7.15%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  59.90  166.61  10.00                9990.00
# 1 2024-02-01   Sell  60.98  166.61  10.16               10149.72
# 2 2024-02-06    Buy  59.94  168.99  10.15               10139.57
# 3 2024-02-20   Sell  60.70  168.99  10.26               10247.43
# 4 2024-02-29    Buy  60.02  170.39  10.25               10237.18
#
# ==================================================
# Processing stock: PEP
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $11,053.20
#   Return: 10.53%
#   Number of trades: 17
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $7,584.75
#   Return: -24.15%
#   Number of trades: 2
#
# Comparison:
#   Difference: $3,468.45
#   Percentage Difference: 34.68%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-02-09    Buy  167.67   59.52  10.00                9990.00
# 1 2024-02-12   Sell  170.61   59.52  10.15               10144.56
# 2 2024-02-14    Buy  167.52   60.44  10.14               10134.42
# 3 2024-02-23   Sell  169.60   60.44  10.25               10240.37
# 4 2024-02-26    Buy  168.26   60.74  10.24               10230.13
#
# ==================================================
# Processing stock: MRK
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $9,990.00
#   Return: -0.10%
#   Number of trades: 1
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $7,135.06
#   Return: -28.65%
#   Number of trades: 2
#
# Comparison:
#   Difference: $2,854.94
#   Percentage Difference: 28.55%
#
# First few VWAP transactions:
#         Date Action   Price  Shares   Fee  Portfolio Value After
# 0 2024-07-30    Buy  115.25   86.59  10.0                 9990.0
#
# ==================================================
# Processing stock: ABT
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,033.44
#   Return: 0.33%
#   Number of trades: 6
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $12,174.83
#   Return: 21.75%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-2,141.39
#   Percentage Difference: -21.41%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-02-02    Buy  112.11   89.02  10.00                9990.00
# 1 2024-02-06   Sell  114.00   89.02  10.15               10138.13
# 2 2024-02-09    Buy  111.81   90.49  10.14               10127.99
# 3 2024-02-15   Sell  113.64   90.49  10.28               10273.00
# 4 2024-03-18    Buy  112.44   91.18  10.27               10262.73
#
# ==================================================
# Processing stock: T
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,446.55
#   Return: 4.47%
#   Number of trades: 10
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $16,181.95
#   Return: 61.82%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-5,735.40
#   Percentage Difference: -57.35%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-02-08    Buy  16.82  593.34  10.00                9990.00
# 1 2024-03-05   Sell  17.17  593.34  10.19               10177.46
# 2 2024-03-14    Buy  17.01  597.13  10.18               10167.28
# 3 2024-03-18   Sell  17.30  597.13  10.33               10320.02
# 4 2024-03-22    Buy  16.98  606.56  10.32               10309.70
#
# ==================================================
# Processing stock: CRM
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,003.44
#   Return: 0.03%
#   Number of trades: 3
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $10,282.20
#   Return: 2.82%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-278.76
#   Percentage Difference: -2.79%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-15    Buy  272.90   36.57  10.00                9990.00
# 1 2024-09-25   Sell  274.09   36.57  10.02               10013.45
# 2 2025-03-10    Buy  272.90   36.62  10.01               10003.44
#
# ==================================================
# Processing stock: WMT
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,000.00
#   Return: 0.00%
#   Number of trades: 0
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $17,721.54
#   Return: 77.22%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-7,721.54
#   Percentage Difference: -77.22%
#
# ==================================================
# Processing stock: Sheet1
# ==================================================
# Skipping sheet Sheet1: Not enough rows.
#
# ==================================================
# Processing stock: ABBV
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $13,302.99
#   Return: 33.03%
#   Number of trades: 12
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $11,918.30
#   Return: 19.18%
#   Number of trades: 2
#
# Comparison:
#   Difference: $1,384.69
#   Percentage Difference: 13.85%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-04    Buy  167.90   59.44  10.00                9990.00
# 1 2024-06-20   Sell  172.13   59.44  10.23               10221.18
# 2 2024-07-02    Buy  165.96   61.47  10.22               10210.96
# 3 2024-07-17   Sell  175.27   61.47  10.77               10763.08
# 4 2024-11-12    Buy  171.09   62.78  10.76               10752.32
#
# ==================================================
# Processing stock: COST
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,000.00
#   Return: 0.00%
#   Number of trades: 0
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $15,098.54
#   Return: 50.99%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-5,098.54
#   Percentage Difference: -50.99%
#
# ==================================================
# Processing stock: AVGO
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $19,579.34
#   Return: 95.79%
#   Number of trades: 6
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $23,180.34
#   Return: 131.80%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-3,601.00
#   Percentage Difference: -36.01%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-08-07    Buy  136.27   73.24  10.00                9990.00
# 1 2024-08-15   Sell  166.13   73.24  12.17               12155.19
# 2 2024-09-06    Buy  137.00   88.55  12.16               12143.03
# 3 2024-09-12   Sell  164.56   88.55  14.57               14557.22
# 4 2025-04-03    Buy  154.01   94.33  14.56               14542.66
#
# ==================================================
# Processing stock: DHR
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $11,524.22
#   Return: 15.24%
#   Number of trades: 5
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $8,548.42
#   Return: -14.52%
#   Number of trades: 2
#
# Comparison:
#   Difference: $2,975.80
#   Percentage Difference: 29.76%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-15    Buy  239.66   41.64  10.00                9990.00
# 1 2024-04-23   Sell  253.11   41.64  10.54               10528.96
# 2 2024-07-02    Buy  240.41   43.71  10.53               10518.43
# 3 2024-07-23   Sell  264.18   43.71  11.55               11535.76
# 4 2024-10-24    Buy  248.00   46.42  11.54               11524.22
#
# ==================================================
# Processing stock: MCD
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,490.83
#   Return: 4.91%
#   Number of trades: 8
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $9,954.62
#   Return: -0.45%
#   Number of trades: 2
#
# Comparison:
#   Difference: $536.21
#   Percentage Difference: 5.36%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  294.65   33.87  10.00                9990.00
# 1 2024-02-01   Sell  298.08   33.87  10.10               10085.87
# 2 2024-02-05    Buy  285.97   35.20  10.09               10075.78
# 3 2024-02-20   Sell  292.65   35.20  10.30               10290.98
# 4 2024-02-29    Buy  292.28   35.14  10.29               10280.69
#
# ==================================================
# Processing stock: MDT
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $11,183.10
#   Return: 11.83%
#   Number of trades: 12
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $10,592.09
#   Return: 5.92%
#   Number of trades: 2
#
# Comparison:
#   Difference: $591.01
#   Percentage Difference: 5.91%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-02-09    Buy  84.99  117.43  10.00                9990.00
# 1 2024-03-27   Sell  86.92  117.43  10.21               10196.81
# 2 2024-04-03    Buy  85.00  119.72  10.20               10186.61
# 3 2024-05-15   Sell  84.72  119.72  10.14               10132.54
# 4 2024-05-23    Buy  81.38  124.26  10.13               10122.41
#
# ==================================================
# Processing stock: BMY
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,268.71
#   Return: 2.69%
#   Number of trades: 5
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $9,204.25
#   Return: -7.96%
#   Number of trades: 2
#
# Comparison:
#   Difference: $1,064.46
#   Percentage Difference: 10.64%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  49.39  202.07  10.00                9990.00
# 1 2024-02-21   Sell  50.91  202.07  10.29               10277.09
# 2 2024-04-10    Buy  50.29  203.95  10.28               10266.81
# 3 2024-07-26   Sell  50.45  203.95  10.29               10278.99
# 4 2025-04-16    Buy  49.36  207.83  10.28               10268.71
#
# ==================================================
# Processing stock: NKE
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,182.17
#   Return: 1.82%
#   Number of trades: 3
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $5,797.99
#   Return: -42.02%
#   Number of trades: 2
#
# Comparison:
#   Difference: $4,384.18
#   Percentage Difference: 43.84%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  101.53   98.30  10.00                9990.00
# 1 2024-02-07   Sell  103.79   98.30  10.20               10192.36
# 2 2024-03-01    Buy  101.88   99.84  10.19               10182.17
#
# ==================================================
# Processing stock: PM
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,358.72
#   Return: 3.59%
#   Number of trades: 4
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $19,142.17
#   Return: 91.42%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-8,783.45
#   Percentage Difference: -87.83%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  91.76  108.76  10.00                9990.00
# 1 2024-03-08   Sell  92.68  108.76  10.08               10069.80
# 2 2024-03-22    Buy  90.88  110.58  10.07               10059.73
# 3 2024-04-19   Sell  93.77  110.58  10.37               10358.72
#
# ==================================================
# Processing stock: TMO
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $11,278.15
#   Return: 12.78%
#   Number of trades: 11
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $7,429.43
#   Return: -25.71%
#   Number of trades: 2
#
# Comparison:
#   Difference: $3,848.72
#   Percentage Difference: 38.49%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  538.98   18.52  10.00                9990.00
# 1 2024-02-01   Sell  552.23   18.52  10.23               10217.07
# 2 2024-02-13    Buy  538.60   18.93  10.22               10206.85
# 3 2024-02-14   Sell  548.27   18.93  10.38               10368.37
# 4 2024-04-16    Buy  554.55   18.66  10.37               10358.00
#
# ==================================================
# Processing stock: LIN
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $12,623.42
#   Return: 26.23%
#   Number of trades: 10
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $11,369.40
#   Return: 13.69%
#   Number of trades: 2
#
# Comparison:
#   Difference: $1,254.02
#   Percentage Difference: 12.54%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  404.83   24.65  10.00                9990.00
# 1 2024-02-01   Sell  408.65   24.65  10.07               10063.15
# 2 2024-02-02    Buy  407.09   24.67  10.06               10053.09
# 3 2024-02-06   Sell  415.56   24.67  10.25               10241.62
# 4 2024-05-02    Buy  419.62   24.36  10.24               10231.38
#
# ==================================================
# Processing stock: LOW
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,613.00
#   Return: 6.13%
#   Number of trades: 5
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $9,862.65
#   Return: -1.37%
#   Number of trades: 2
#
# Comparison:
#   Difference: $750.35
#   Percentage Difference: 7.50%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  214.52   46.52  10.00                9990.00
# 1 2024-02-01   Sell  220.23   46.52  10.25               10234.85
# 2 2024-05-21    Buy  224.86   45.43  10.23               10224.62
# 3 2024-07-12   Sell  234.08   45.43  10.63               10623.62
# 4 2025-03-11    Buy  232.67   45.57  10.62               10613.00
#
# ==================================================
# Processing stock: HON
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $12,327.97
#   Return: 23.28%
#   Number of trades: 18
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $10,700.57
#   Return: 7.01%
#   Number of trades: 2
#
# Comparison:
#   Difference: $1,627.40
#   Percentage Difference: 16.27%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-02-01    Buy  197.31   50.58  10.00                9990.00
# 1 2024-03-07   Sell  202.61   50.58  10.25               10237.76
# 2 2024-03-14    Buy  196.35   52.04  10.24               10227.52
# 3 2024-03-20   Sell  201.18   52.04  10.47               10458.94
# 4 2024-04-03    Buy  197.97   52.73  10.46               10448.48
#
# ==================================================
# Processing stock: AMD
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $11,778.65
#   Return: 17.79%
#   Number of trades: 5
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $9,102.87
#   Return: -8.97%
#   Number of trades: 2
#
# Comparison:
#   Difference: $2,675.78
#   Percentage Difference: 26.76%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-04-12    Buy  163.28   61.12  10.00                9990.00
# 1 2024-07-08   Sell  178.69   61.12  10.92               10910.61
# 2 2024-07-17    Buy  159.43   68.30  10.91               10899.70
# 3 2024-10-08   Sell  172.80   68.30  11.80               11790.44
# 4 2024-10-15    Buy  156.64   75.12  11.79               11778.65
#
# ==================================================
# Processing stock: SBUX
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $12,603.66
#   Return: 26.04%
#   Number of trades: 10
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $9,959.79
#   Return: -0.40%
#   Number of trades: 2
#
# Comparison:
#   Difference: $2,643.87
#   Percentage Difference: 26.44%
#
# First few VWAP transactions:
#         Date Action  Price  Shares    Fee  Portfolio Value After
# 0 2024-01-31    Buy  93.03  107.28  10.00                9990.00
# 1 2024-02-06   Sell  95.67  107.28  10.26               10253.22
# 2 2024-02-15    Buy  93.22  109.77  10.25               10242.97
# 3 2024-02-21   Sell  95.02  109.77  10.43               10419.92
# 4 2024-02-28    Buy  93.00  111.82  10.42               10409.50
#
# ==================================================
# Processing stock: ORCL
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $12,611.99
#   Return: 26.12%
#   Number of trades: 2
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $20,245.43
#   Return: 102.45%
#   Number of trades: 2
#
# Comparison:
#   Difference: $-7,633.44
#   Percentage Difference: -76.33%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2025-04-04    Buy  128.27    77.8  10.00                9990.00
# 1 2025-05-13   Sell  162.27    77.8  12.62               12611.99
#
# ==================================================
# Processing stock: UPS
# ==================================================
#
# VWAP Strategy:
#   Final Portfolio Value: $10,533.52
#   Return: 5.34%
#   Number of trades: 3
#
# Buy-and-Hold Strategy:
#   Final Portfolio Value: $6,371.67
#   Return: -36.28%
#   Number of trades: 2
#
# Comparison:
#   Difference: $4,161.85
#   Percentage Difference: 41.62%
#
# First few VWAP transactions:
#         Date Action   Price  Shares    Fee  Portfolio Value After
# 0 2024-01-30    Buy  145.06   68.80  10.00                9990.00
# 1 2024-03-07   Sell  153.41   68.80  10.55               10544.06
# 2 2024-03-26    Buy  143.79   73.18  10.54               10533.52
#
# ================================================================================
#                        STRATEGY COMPARISON SUMMARY REPORT
# ================================================================================
#
# Total Stocks Analyzed: 50
#
# VWAP Strategy Performance:
#   Winning Stocks: 49 (98.0%)
#   Losing Stocks: 1 (2.0%)
#   Average Return: 17.00%
#
# Buy-and-Hold Strategy Performance:
#   Winning Stocks: 33 (66.0%)
#   Losing Stocks: 17 (34.0%)
#   Average Return: 22.75%
#
# Strategy Comparison:
#   VWAP outperformed Buy-and-Hold in 28 stocks (56.0%)
#   Average outperformance: -5.75%
#
# Best Performing VWAP Stock:
#   TSLA: 108.43% ($20,843.18)
#
# Best Performing Buy-and-Hold Stock:
#   NVDA: 199.78% ($29,977.89)
#
# ================================================================================
